# %%
import tensorflow
import SimpleITK as sitk
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns 

import os
import glob

##import SimpleITK as sitk

from PIL import Image

from imageio import imread

# %matplotlib inline
from IPython.display import clear_output
pd.options.mode.chained_assignment = None

# %%
annotations = pd.read_csv('/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/annotations.csv')
candidates = pd.read_csv('/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/candidates.csv')

# %%
annotations.head()
# Out:
#                                            seriesuid      coordX      coordY  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421 -175.319272
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651 -211.925149
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017 -140.944586
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824  192.102405
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547  172.464881
#
#        coordZ  diameter_mm
# 0 -298.387506     5.651471
# 1 -227.121250     4.224708
# 2  876.374496     5.786348
# 3 -391.081276     8.143262
# 4 -405.493732    18.545150

# %%
candidates['class'].sum()
# Out:
# 1351

# %%
candidates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551065 entries, 0 to 551064
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   seriesuid  551065 non-null  object
#  1   coordX     551065 non-null  float64
#  2   coordY     551065 non-null  float64
#  3   coordZ     551065 non-null  float64
#  4   class      551065 non-null  int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 21.0+ MB

# %%
print(len(candidates[candidates['class'] == 1]))
print(len(candidates[candidates['class'] == 0]))
# Out:
# 1351
# 549714

# %%
import multiprocessing
num_cores = multiprocessing.cpu_count()
print(num_cores)
# Out:
# 4

# %%
class CTScan(object):
    def __init__(self, filename = None, coords = None):
        self.filename = filename
        self.coords = coords
        self.ds = None
        self.image = None

    def reset_coords(self, coords):
        self.coords = coords

    def read_mhd_image(self):
        path = glob.glob('../data/raw/*/'+ self.filename + '.mhd')
        self.ds = sitk.ReadImage(path[0])
        self.image = sitk.GetArrayFromImage(self.ds)

    def get_resolution(self):
        return self.ds.GetSpacing()

    def get_origin(self):
        return self.ds.GetOrigin()

    def get_ds(self):
        return self.ds

    def get_voxel_coords(self):
        origin = self.get_origin()
        resolution = self.get_resolution()
        voxel_coords = [np.absolute(self.coords[j]-origin[j])/resolution[j] \
            for j in range(len(self.coords))]
        return tuple(voxel_coords)
    
    def get_image(self):
        return self.image
    
    def get_subimage(self, width):
        self.read_mhd_image()
        x, y, z = self.get_voxel_coords()
        subImage = self.image[z, y-width/2:y+width/2, x-width/2:x+width/2]
        return subImage   
    
    def normalizePlanes(self, npzarray):
        maxHU = 400.
        minHU = -1000.
        npzarray = (npzarray - minHU) / (maxHU - minHU)
        npzarray[npzarray>1] = 1.
        npzarray[npzarray<0] = 0.
        return npzarray
    
    def save_image(self, filename, width):
        image = self.get_subimage(width)
        image = self.normalizePlanes(image)
        Image.fromarray(image*255).convert('L').save(filename)

# %%
positives = candidates[candidates['class']==1].index  
negatives = candidates[candidates['class']==0].index

# %%
positives
# Out:
# Int64Index([    13,     78,   1303,   3050,   3052,   3080,   3223,   3285,
#               3287,   3289,
#             ...
#             545928, 546205, 546372, 546400, 547498, 548674, 550171, 550334,
#             550810, 550906],
#            dtype='int64', length=1351)

# %%
np.random.seed(42)
negIndexes = np.random.choice(negatives, len(positives)*5, replace = False)

# %%
candidatesDf = candidates.iloc[list(positives)+list(negIndexes)]

# %%
from sklearn.model_selection import train_test_split
X = candidatesDf.iloc[:,:-1]
y = candidatesDf.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_train.size
# Out:
# 25936

# %%
y_train
# Out:
# 178085    0
# 108126    0
# 416697    0
# 342095    0
# 116478    0
#          ..
# 469116    0
# 164439    0
# 333192    1
# 358382    0
# 536292    0
# Name: class, Length: 6484, dtype: int64

# %%
y_test
# Out:
# 189342    0
# 145102    0
# 31546     0
# 441280    1
# 215578    0
#          ..
# 87015     0
# 245189    0
# 533231    0
# 52755     0
# 379730    0
# Name: class, Length: 1622, dtype: int64

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.20, random_state = 42)

# %%
X_train.size
# Out:
# 20748

# %%
X_train
# Out:
#                                                 seriesuid      coordX  \
# 59270   1.3.6.1.4.1.14519.5.2.1.6279.6001.132817748896...  -97.808167
# 150277  1.3.6.1.4.1.14519.5.2.1.6279.6001.182192086929...   58.990000
# 432208  1.3.6.1.4.1.14519.5.2.1.6279.6001.397522780537...  -50.307219
# 423122  1.3.6.1.4.1.14519.5.2.1.6279.6001.339882192295... -106.731000
# 344581  1.3.6.1.4.1.14519.5.2.1.6279.6001.296863826932...   67.240000
# ...                                                   ...         ...
# 323102  1.3.6.1.4.1.14519.5.2.1.6279.6001.279953669991...  -22.239361
# 94004   1.3.6.1.4.1.14519.5.2.1.6279.6001.149893110752...   52.320000
# 459476  1.3.6.1.4.1.14519.5.2.1.6279.6001.503980049263... -112.420630
# 241550  1.3.6.1.4.1.14519.5.2.1.6279.6001.230416590143...  -27.740000
# 211695  1.3.6.1.4.1.14519.5.2.1.6279.6001.215785045378...  -58.670000
#
#             coordY      coordZ
# 59270     3.897917 -201.030000
# 150277  -24.230000  -18.320000
# 432208  159.439740 -113.418797
# 423122 -104.468000  751.163333
# 344581  -32.590000 -107.790000
# ...            ...         ...
# 323102   84.653132 -161.740390
# 94004    65.000000 -117.870000
# 459476   37.648160  -67.928064
# 241550 -121.660000 -254.130000
# 211695  163.720000 -641.700000
#
# [5187 rows x 4 columns]

# %%
y_train
# Out:
# 59270     0
# 150277    0
# 432208    0
# 423122    0
# 344581    0
#          ..
# 323102    0
# 94004     0
# 459476    1
# 241550    0
# 211695    0
# Name: class, Length: 5187, dtype: int64

# %%
len(X_train)
# Out:
# 5187

# %%
X_train.to_pickle('/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/preprocessed_data/traindata')
X_test.to_pickle('/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/preprocessed_data/testdata')
X_val.to_pickle('/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/preprocessed_data/valdata')

# %%
def normalizePlanes(npzarray):
    maxHU = 400.
    minHU = -1000.
    npzarray = (npzarray - minHU) / (maxHU - minHU)
    npzarray[npzarray>1] = 1.
    npzarray[npzarray<0] = 0.
    return npzarray

# %%
print('number of positive cases are ' + str(y_train.sum()))
print('total set size is ' + str(len(y_train)))
print('percentage of positive cases are ' + str(y_train.sum()*1.0/len(y_train)))
# Out:
# number of positive cases are 845
# total set size is 5187
# percentage of positive cases are 0.16290726817042606

# %%
tempDf = X_train[y_train == 1]
tempDf = tempDf.set_index(X_train[y_train == 1].index + 1000000)
X_train_new = X_train.append(tempDf)
tempDf = tempDf.set_index(X_train[y_train == 1].index + 2000000)
X_train_new = X_train_new.append(tempDf)

ytemp = y_train.reindex(X_train[y_train == 1].index + 1000000)
ytemp.loc[:] = 1
y_train_new = y_train.append(ytemp)
ytemp = y_train.reindex(X_train[y_train == 1].index + 2000000)
ytemp.loc[:] = 1
y_train_new = y_train_new.append(ytemp)

print(len(X_train_new), len(y_train_new))
# Out:
# 6877 6877
# /tmp/ipykernel_5082/3020267698.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   X_train_new = X_train.append(tempDf)
# /tmp/ipykernel_5082/3020267698.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   X_train_new = X_train_new.append(tempDf)
# /tmp/ipykernel_5082/3020267698.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y_train_new = y_train.append(ytemp)
# /tmp/ipykernel_5082/3020267698.py:12: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y_train_new = y_train_new.append(ytemp)

# %%
X_train_new
# Out:
#                                                  seriesuid      coordX  \
# 59270    1.3.6.1.4.1.14519.5.2.1.6279.6001.132817748896...  -97.808167
# 150277   1.3.6.1.4.1.14519.5.2.1.6279.6001.182192086929...   58.990000
# 432208   1.3.6.1.4.1.14519.5.2.1.6279.6001.397522780537...  -50.307219
# 423122   1.3.6.1.4.1.14519.5.2.1.6279.6001.339882192295... -106.731000
# 344581   1.3.6.1.4.1.14519.5.2.1.6279.6001.296863826932...   67.240000
# ...                                                    ...         ...
# 2436163  1.3.6.1.4.1.14519.5.2.1.6279.6001.404768898286...   88.955096
# 2013078  1.3.6.1.4.1.14519.5.2.1.6279.6001.106719103982...  -57.089458
# 2352132  1.3.6.1.4.1.14519.5.2.1.6279.6001.300246184547...  100.136716
# 2188812  1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895...  118.180000
# 2459476  1.3.6.1.4.1.14519.5.2.1.6279.6001.503980049263... -112.420630
#
#              coordY       coordZ
# 59270      3.897917  -201.030000
# 150277   -24.230000   -18.320000
# 432208   159.439740  -113.418797
# 423122  -104.468000   751.163333
# 344581   -32.590000  -107.790000
# ...             ...          ...
# 2436163  224.250740  -586.901865
# 2013078   72.608061  1791.668825
# 2352132    3.904990   -93.909072
# 2188812  -42.910000  -247.440000
# 2459476   37.648160   -67.928064
#
# [6877 rows x 4 columns]

# %%
y_train_new
# Out:
# 59270      0.0
# 150277     0.0
# 432208     0.0
# 423122     0.0
# 344581     0.0
#           ...
# 2436163    1.0
# 2013078    1.0
# 2352132    1.0
# 2188812    1.0
# 2459476    1.0
# Name: class, Length: 6877, dtype: float64

# %%
X_train_new.index
# Out:
# Int64Index([  59270,  150277,  432208,  423122,  344581,   75111,  246217,
#              292479,  147683,  468235,
#             ...
#             2282167, 2300642, 2021354, 2461166, 2332952, 2436163, 2013078,
#             2352132, 2188812, 2459476],
#            dtype='int64', length=6877)

# %%
import scipy.misc

# %%
import cv2

# %%
from PIL import ImageEnhance

class PreProcessing(object):
    def __init__(self, image = None):
        self.image = image
    
    def subtract_mean(self):
        self.image = (self.image/255.0 - 0.25)*255
        return self.image
    
    def downsample_data(self):
        self.image = cv2.resize(self.image, (40,40), interpolation = cv2.INTER_AREA)
        return self.image

    def upsample_data(self):
        self.image = cv2.resize(self.image, (224, 224), interpolation = cv2.INTER_CUBIC)
        return self.image

# %% [markdown]
# Imported the preprocessed and segmented dataset

# %%
dirName = '/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/data/train/'
plt.figure(figsize = (10,10))
inp = imread(dirName + 'image_'+ str(30517) + '.jpg')
print ("Original shape of input image: ", inp.shape)
plt.subplot(221)
plt.imshow(inp, cmap='gray')
plt.grid(False)

inp = PreProcessing(inp).upsample_data()
Pp = PreProcessing(inp)

inp2 = Pp.subtract_mean()
plt.subplot(222)
plt.imshow(inp2, cmap='gray')
plt.grid(False)

inp3 = ImageEnhance.Contrast(Image.fromarray(inp))
contrast = 1.5
inp3 = inp3.enhance(contrast)
plt.subplot(223)
plt.imshow(inp3, cmap='gray')
plt.grid(False)

inp4 = Pp.downsample_data()
plt.subplot(224)
plt.imshow(inp4,cmap='gray')
plt.grid(False)
# Out:
# Original shape of input image:  (50, 50)

# %%
inp.shape
# Out:
# (224, 224)

# %%
inp.dtype
# Out:
# dtype('uint8')

# %%
y_train_new.values.astype(int)
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# Training

# %%
dirName
# Out:
# '/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/data/train/'

# %%
train_filenames =\
X_train_new.index.to_series().apply(lambda x:\
                                    '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_'+str(x)+'.jpg')
train_filenames.values.astype(str)
# Out:
# array(['/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_59270.jpg',
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_150277.jpg',
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_432208.jpg',
#        ...,
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_2352132.jpg',
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_2188812.jpg',
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_2459476.jpg'],
#       dtype='<U80')

# %%
train_filenames.values.astype(str)
# Out:
# array(['/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_59270.jpg',
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_150277.jpg',
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_432208.jpg',
#        ...,
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_2352132.jpg',
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_2188812.jpg',
#        '/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/data/train/image_2459476.jpg'],
#       dtype='<U80')

# %%
dataset_file = 'traindatalabels.txt'
filenames = train_filenames.values.astype(str)
train_filenames =X_train_new.index.to_series().apply(lambda x:filenames)
labels = y_train_new.values.astype(int)
traindata = np.zeros(filenames.size,\
                     dtype=[('var1', 'S36'), ('var2', int)])
traindata['var1'] = filenames
traindata['var2'] = labels

np.savetxt(dataset_file, traindata, fmt="%10s %d")

# %%
traindata
# Out:
# array([(b'/content/gdrive/My Drive/lungcancer/', 0),
#        (b'/content/gdrive/My Drive/lungcancer/', 0),
#        (b'/content/gdrive/My Drive/lungcancer/', 0), ...,
#        (b'/content/gdrive/My Drive/lungcancer/', 1),
#        (b'/content/gdrive/My Drive/lungcancer/', 1),
#        (b'/content/gdrive/My Drive/lungcancer/', 1)],
#       dtype=[('var1', 'S36'), ('var2', '<i8')])

# %%
import h5py
h5f = h5py.File('/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/data/traindataset.h5', 'r')
X_train_images = h5f['X']
Y_train_labels = h5f['Y']

h5f2 = h5py.File('/home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/data/valdataset.h5', 'r')
X_val_images = h5f2['X']
Y_val_labels = h5f2['Y']

# %%
X_train_images
# Out:
# <HDF5 dataset "X": shape (5187, 50, 50), type "<f4">

# %%
Y_train_labels
# Out:
# <HDF5 dataset "Y": shape (5187, 2), type "<f4">

# %% [markdown]
# Testing_image_processing

# %%
X_train_processing = np.array(X_train_images)
X_val_processing = np.array(X_val_images)

# %%
print(X_train_processing.shape)
print(X_val_processing.shape)
# Out:
# (5187, 50, 50)
# (1297, 50, 50)

# %%
print(X_train_processing.dtype)
print(X_val_processing.dtype)
# Out:
# float32
# float32

# %%
img_test = X_train_processing[1000]
img_test_downsampled = PreProcessing(img_test).downsample_data()
img_test_upsampled = PreProcessing(img_test).upsample_data()

# %%
print(Y_train_labels[1000])
# Out:
# [1. 0.]

# %%
plt.subplot(121)
plt.imshow(img_test,cmap='gray')
plt.subplot(122)
plt.imshow(img_test_downsampled,cmap='gray')

# %%
plt.subplot(121)
plt.imshow(img_test,cmap='gray')
plt.subplot(122)
plt.imshow(img_test_upsampled,cmap='gray')

# %%
img_test_subtracted_mean = PreProcessing(img_test_upsampled).subtract_mean()
plt.subplot(121)
plt.imshow(img_test_upsampled,cmap='gray')
plt.subplot(122)
plt.imshow(img_test_subtracted_mean,cmap='gray')

# %% [markdown]
# testing cv2 BRISK algorithm

# %% [markdown]
# need some work and research

# %%
import cv2
brisk = cv2.BRISK_create(50)
img_BRISK_1 = img_test_upsampled.copy()
rgb = cv2.cvtColor(img_BRISK_1, cv2.COLOR_GRAY2RGB)
img_BRISK_2 = rgb*1000
img_BRISK_3 = np.array(img_BRISK_2, dtype=np.uint8)
img_contr_copy = img_BRISK_3.copy()

plt.subplot(221)
plt.imshow(img_BRISK_3, cmap='gray')
kpts_1, des_1 = brisk.detectAndCompute(img_BRISK_3, None)

image_BRISK_1 = cv2.drawKeypoints(image=img_BRISK_3, outImage=img_BRISK_3, keypoints=kpts_1, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.subplot(222)
plt.imshow(image_BRISK_1, cmap='gray')


inp_contr = ImageEnhance.Contrast(Image.fromarray(img_contr_copy))
contrast = 1.5
img_contr = inp_contr.enhance(contrast)
plt.subplot(223)
plt.imshow(img_contr, cmap='gray')
img_BRISK_4 = np.array(img_contr)
kpts_2, des_2 = brisk.detectAndCompute(img_BRISK_4, None)

image_BRISK_2 = cv2.drawKeypoints(image=img_BRISK_4, outImage=img_BRISK_4, keypoints=kpts_2, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.subplot(224)
plt.imshow(image_BRISK_2, cmap='gray')

# %% [markdown]
# test both with other CV2 algorithms and then implement all those algorithms with DL model self defined.

# %% [markdown]
# Converting to training dataset

# %%
X_train_images_np = np.expand_dims(np.array(X_train_images), axis = 3)
y_train_labels_np = np.array(Y_train_labels)
X_val_images_np = np.expand_dims(np.array(X_val_images), axis = 3)
y_val_labels_np = np.array(Y_val_labels)

# %%
print(X_train_images_np.shape)
print(y_train_labels_np.shape)
print(X_val_images_np.shape)
print(y_val_labels_np.shape)
# Out:
# (5187, 50, 50, 1)
# (5187, 2)
# (1297, 50, 50, 1)
# (1297, 2)

# %%
print(X_train_images_np.dtype)
print(y_train_labels_np.dtype)
print(X_val_images_np.dtype)
print(y_val_labels_np.dtype)
# Out:
# float32
# float32
# float32
# float32

# %% [markdown]
# processing for test dataset

# %%
h5f2 = h5py.File('//home/aamir/app/Lung_cancer/Dataset/Dataset_LUNA_16/Dataset_LUNA_16/data/testdataset.h5', 'r')
X_test_images = h5f2['X']
Y_test_labels = h5f2['Y']

# %%
X_test_images_np = np.expand_dims(np.array(X_test_images), axis = 3)
y_test_labels_np = np.array(Y_test_labels)

# %%
print(X_test_images_np.shape)
print(y_test_labels_np.shape)
# Out:
# (1622, 50, 50, 1)
# (1622, 2)

# %%
print(X_test_images_np.dtype)
print(y_test_labels_np.dtype)
# Out:
# float32
# float32

# %% [markdown]
# Model Making and Model Training

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout,BatchNormalization,AveragePooling2D

from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# model based on deep cnn

# %%
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(50, 50, 1)))
	model.add(BatchNormalization())
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.1))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.3))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.4))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.5))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(BatchNormalization())
	model.add(Dropout(0.5))
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'));return model

mobile = define_model()
# Out:
# 2022-05-13 22:35:36.050977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-13 22:35:36.102134: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/aamir/.local/lib/python3.10/site-packages/cv2/../../lib64:/usr/local/cuda/extras/CUPTI/lib64:
# 2022-05-13 22:35:36.102156: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-05-13 22:35:36.102568: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
mobile.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 32)        320
#
#  batch_normalization (BatchN  (None, 50, 50, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 50, 50, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 32)       0
#  )
#
#  dropout (Dropout)           (None, 25, 25, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 25, 25, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 25, 25, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 25, 25, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       147584
#
#  batch_normalization_5 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 128)         147584
#
#  batch_normalization_6 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 128)         147584
#
#  batch_normalization_7 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 128)         0
#
#  conv2d_8 (Conv2D)           (None, 3, 3, 128)         147584
#
#  batch_normalization_8 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 3, 3, 128)         147584
#
#  batch_normalization_9 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  batch_normalization_10 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
# =================================================================
# Total params: 914,144
# Trainable params: 911,968
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
op_layer = mobile.output
final_layer = Dense(128,activation='relu',kernel_initializer='he_uniform')(op_layer)
final_layer = Dense(128,activation='relu',kernel_initializer='he_uniform')(final_layer)
final_layer = Dense(2,activation= 'softmax')(final_layer)
from keras.models  import Model

model = Model(inputs = mobile.input , outputs = final_layer)
opt = tensorflow.keras.optimizers.SGD(lr=0.001, momentum=0.9)
import keras
optimizer_sgd = tensorflow.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer_sgd, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /home/aamir/.local/lib/python3.10/site-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 50, 50, 1)]       0
#
#  conv2d (Conv2D)             (None, 50, 50, 32)        320
#
#  batch_normalization (BatchN  (None, 50, 50, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 50, 50, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 32)       0
#  )
#
#  dropout (Dropout)           (None, 25, 25, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 25, 25, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 25, 25, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 25, 25, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       147584
#
#  batch_normalization_5 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 128)         147584
#
#  batch_normalization_6 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 128)         147584
#
#  batch_normalization_7 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 128)         0
#
#  conv2d_8 (Conv2D)           (None, 3, 3, 128)         147584
#
#  batch_normalization_8 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 3, 3, 128)         147584
#
#  batch_normalization_9 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  batch_normalization_10 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 947,426
# Trainable params: 945,250
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
def summarize_diagnostics(hist):
	plt.plot(hist.history["accuracy"])
	plt.plot(hist.history['val_accuracy'])
	plt.plot(hist.history['loss'])
	plt.plot(hist.history['val_loss'])
	plt.title("model accuracy")
	plt.ylabel("Accuracy")
	plt.xlabel("Epoch")
	plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint('classification_deep_conv_model.h5', save_best_only=True),
    keras.callbacks.ReduceLROnPlateau()]

# %%
def run_test_harness():
	
	datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True,zoom_range=0.1)
	
	it_train = datagen.flow(X_train_images_np, y_train_labels_np, batch_size=64)
	
	steps = int(X_train_images_np.shape[0] / 64)
	hist = model.fit_generator(it_train, steps_per_epoch=steps, epochs=500, validation_data=(X_val_images_np, y_val_labels_np), verbose=1, callbacks = callbacks)
	
	_, acc = model.evaluate(X_val_images_np, y_val_labels_np, verbose=1)
	print('> %.3f' % (acc * 100.0))
	
	summarize_diagnostics(hist)


run_test_harness()
# Out:
# WARNING:tensorflow:From <ipython-input-79-218d05b3c372>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/500
# 81/81 [==============================] - 3s 35ms/step - loss: 0.5176 - accuracy: 0.8157 - val_loss: 0.5193 - val_accuracy: 0.8273
# Epoch 2/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.4680 - accuracy: 0.8302 - val_loss: 0.4418 - val_accuracy: 0.8273
# Epoch 3/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.4398 - accuracy: 0.8358 - val_loss: 0.4369 - val_accuracy: 0.8258
# Epoch 4/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.4225 - accuracy: 0.8349 - val_loss: 0.4200 - val_accuracy: 0.8296
# Epoch 5/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.4222 - accuracy: 0.8345 - val_loss: 0.4054 - val_accuracy: 0.8365
# Epoch 6/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.3921 - accuracy: 0.8372 - val_loss: 0.3676 - val_accuracy: 0.8473
# Epoch 7/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.3721 - accuracy: 0.8364 - val_loss: 0.4130 - val_accuracy: 0.8057
# Epoch 8/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.3660 - accuracy: 0.8358 - val_loss: 0.3643 - val_accuracy: 0.8173
# Epoch 9/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.3452 - accuracy: 0.8476 - val_loss: 0.3336 - val_accuracy: 0.8574
# Epoch 10/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.3197 - accuracy: 0.8505 - val_loss: 0.3213 - val_accuracy: 0.8666
# Epoch 11/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.3001 - accuracy: 0.8616 - val_loss: 0.3689 - val_accuracy: 0.8497
# Epoch 12/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.2813 - accuracy: 0.8743 - val_loss: 0.2947 - val_accuracy: 0.8782
# Epoch 13/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.2626 - accuracy: 0.8839 - val_loss: 0.2906 - val_accuracy: 0.8736
# Epoch 14/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.2483 - accuracy: 0.8930 - val_loss: 0.2258 - val_accuracy: 0.9067
# Epoch 15/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.2411 - accuracy: 0.8936 - val_loss: 0.2953 - val_accuracy: 0.8851
# Epoch 16/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.2284 - accuracy: 0.9049 - val_loss: 0.2007 - val_accuracy: 0.9244
# Epoch 17/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.2253 - accuracy: 0.9061 - val_loss: 0.2442 - val_accuracy: 0.8790
# Epoch 18/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.2227 - accuracy: 0.9137 - val_loss: 0.2137 - val_accuracy: 0.9129
# Epoch 19/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.2093 - accuracy: 0.9110 - val_loss: 0.2744 - val_accuracy: 0.8782
# Epoch 20/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.2006 - accuracy: 0.9192 - val_loss: 0.1911 - val_accuracy: 0.9306
# Epoch 21/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.1947 - accuracy: 0.9223 - val_loss: 0.1869 - val_accuracy: 0.9329
# Epoch 22/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.1886 - accuracy: 0.9243 - val_loss: 0.1511 - val_accuracy: 0.9360
# Epoch 23/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1826 - accuracy: 0.9215 - val_loss: 0.1912 - val_accuracy: 0.9275
# Epoch 24/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1920 - accuracy: 0.9237 - val_loss: 0.1741 - val_accuracy: 0.9368
# Epoch 25/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1861 - accuracy: 0.9262 - val_loss: 0.1701 - val_accuracy: 0.9275
# Epoch 26/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1672 - accuracy: 0.9338 - val_loss: 0.1511 - val_accuracy: 0.9429
# Epoch 27/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.1599 - accuracy: 0.9344 - val_loss: 0.1468 - val_accuracy: 0.9460
# Epoch 28/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1559 - accuracy: 0.9399 - val_loss: 0.1691 - val_accuracy: 0.9414
# Epoch 29/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1561 - accuracy: 0.9455 - val_loss: 0.1621 - val_accuracy: 0.9337
# Epoch 30/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1475 - accuracy: 0.9438 - val_loss: 0.1906 - val_accuracy: 0.9322
# Epoch 31/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.1524 - accuracy: 0.9375 - val_loss: 0.1446 - val_accuracy: 0.9414
# Epoch 32/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.1587 - accuracy: 0.9393 - val_loss: 0.1402 - val_accuracy: 0.9453
# Epoch 33/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1505 - accuracy: 0.9412 - val_loss: 0.2097 - val_accuracy: 0.9183
# Epoch 34/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1606 - accuracy: 0.9375 - val_loss: 0.1529 - val_accuracy: 0.9391
# Epoch 35/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.1509 - accuracy: 0.9424 - val_loss: 0.1308 - val_accuracy: 0.9499
# Epoch 36/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.1412 - accuracy: 0.9467 - val_loss: 0.1267 - val_accuracy: 0.9545
# Epoch 37/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1261 - accuracy: 0.9483 - val_loss: 0.1424 - val_accuracy: 0.9399
# Epoch 38/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1328 - accuracy: 0.9506 - val_loss: 0.1589 - val_accuracy: 0.9360
# Epoch 39/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1303 - accuracy: 0.9518 - val_loss: 0.1579 - val_accuracy: 0.9329
# Epoch 40/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1158 - accuracy: 0.9555 - val_loss: 0.1533 - val_accuracy: 0.9360
# Epoch 41/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1205 - accuracy: 0.9537 - val_loss: 0.1984 - val_accuracy: 0.9190
# Epoch 42/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1210 - accuracy: 0.9553 - val_loss: 0.1360 - val_accuracy: 0.9453
# Epoch 43/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1354 - accuracy: 0.9483 - val_loss: 0.2386 - val_accuracy: 0.9136
# Epoch 44/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1479 - accuracy: 0.9435 - val_loss: 0.1379 - val_accuracy: 0.9383
# Epoch 45/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1191 - accuracy: 0.9561 - val_loss: 0.1503 - val_accuracy: 0.9306
# Epoch 46/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1779 - accuracy: 0.9366 - val_loss: 0.1422 - val_accuracy: 0.9453
# Epoch 47/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.1359 - accuracy: 0.9471 - val_loss: 0.1260 - val_accuracy: 0.9514
# Epoch 48/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.1203 - accuracy: 0.9557 - val_loss: 0.1181 - val_accuracy: 0.9545
# Epoch 49/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.1222 - accuracy: 0.9555 - val_loss: 0.1160 - val_accuracy: 0.9537
# Epoch 50/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1149 - accuracy: 0.9573 - val_loss: 0.1165 - val_accuracy: 0.9561
# Epoch 51/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1170 - accuracy: 0.9530 - val_loss: 0.1195 - val_accuracy: 0.9530
# Epoch 52/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1054 - accuracy: 0.9598 - val_loss: 0.1195 - val_accuracy: 0.9514
# Epoch 53/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1054 - accuracy: 0.9574 - val_loss: 0.1207 - val_accuracy: 0.9530
# Epoch 54/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.1093 - accuracy: 0.9582 - val_loss: 0.1189 - val_accuracy: 0.9537
# Epoch 55/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.1000 - accuracy: 0.9639 - val_loss: 0.1160 - val_accuracy: 0.9553
# Epoch 56/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0920 - accuracy: 0.9654 - val_loss: 0.1161 - val_accuracy: 0.9522
# Epoch 57/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0957 - accuracy: 0.9654 - val_loss: 0.1145 - val_accuracy: 0.9530
# Epoch 58/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0960 - accuracy: 0.9651 - val_loss: 0.1162 - val_accuracy: 0.9576
# Epoch 59/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0920 - accuracy: 0.9666 - val_loss: 0.1130 - val_accuracy: 0.9568
# Epoch 60/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1007 - accuracy: 0.9635 - val_loss: 0.1133 - val_accuracy: 0.9545
# Epoch 61/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0947 - accuracy: 0.9612 - val_loss: 0.1141 - val_accuracy: 0.9537
# Epoch 62/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0902 - accuracy: 0.9684 - val_loss: 0.1109 - val_accuracy: 0.9545
# Epoch 63/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.1016 - accuracy: 0.9623 - val_loss: 0.1225 - val_accuracy: 0.9537
# Epoch 64/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0856 - accuracy: 0.9692 - val_loss: 0.1121 - val_accuracy: 0.9553
# Epoch 65/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0820 - accuracy: 0.9705 - val_loss: 0.1105 - val_accuracy: 0.9561
# Epoch 66/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0860 - accuracy: 0.9670 - val_loss: 0.1117 - val_accuracy: 0.9530
# Epoch 67/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0948 - accuracy: 0.9674 - val_loss: 0.1131 - val_accuracy: 0.9561
# Epoch 68/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0841 - accuracy: 0.9709 - val_loss: 0.1136 - val_accuracy: 0.9553
# Epoch 69/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0802 - accuracy: 0.9697 - val_loss: 0.1131 - val_accuracy: 0.9537
# Epoch 70/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0779 - accuracy: 0.9731 - val_loss: 0.1050 - val_accuracy: 0.9591
# Epoch 71/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0850 - accuracy: 0.9686 - val_loss: 0.1121 - val_accuracy: 0.9591
# Epoch 72/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0844 - accuracy: 0.9699 - val_loss: 0.1277 - val_accuracy: 0.9491
# Epoch 73/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0968 - accuracy: 0.9614 - val_loss: 0.1250 - val_accuracy: 0.9483
# Epoch 74/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0898 - accuracy: 0.9656 - val_loss: 0.1088 - val_accuracy: 0.9545
# Epoch 75/500
# 81/81 [==============================] - 2s 31ms/step - loss: 0.0830 - accuracy: 0.9672 - val_loss: 0.1048 - val_accuracy: 0.9568
# Epoch 76/500
# 81/81 [==============================] - 3s 31ms/step - loss: 0.0808 - accuracy: 0.9711 - val_loss: 0.1043 - val_accuracy: 0.9584
# Epoch 77/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0832 - accuracy: 0.9711 - val_loss: 0.1092 - val_accuracy: 0.9591
# Epoch 78/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0883 - accuracy: 0.9697 - val_loss: 0.1105 - val_accuracy: 0.9522
# Epoch 79/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0813 - accuracy: 0.9711 - val_loss: 0.1092 - val_accuracy: 0.9537
# Epoch 80/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0781 - accuracy: 0.9688 - val_loss: 0.1106 - val_accuracy: 0.9507
# Epoch 81/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0752 - accuracy: 0.9731 - val_loss: 0.1063 - val_accuracy: 0.9568
# Epoch 82/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0759 - accuracy: 0.9719 - val_loss: 0.1108 - val_accuracy: 0.9522
# Epoch 83/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0775 - accuracy: 0.9713 - val_loss: 0.1182 - val_accuracy: 0.9522
# Epoch 84/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0808 - accuracy: 0.9694 - val_loss: 0.1164 - val_accuracy: 0.9522
# Epoch 85/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0717 - accuracy: 0.9733 - val_loss: 0.1115 - val_accuracy: 0.9537
# Epoch 86/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0799 - accuracy: 0.9711 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 87/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0736 - accuracy: 0.9746 - val_loss: 0.1078 - val_accuracy: 0.9553
# Epoch 88/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0750 - accuracy: 0.9725 - val_loss: 0.1074 - val_accuracy: 0.9561
# Epoch 89/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0718 - accuracy: 0.9731 - val_loss: 0.1078 - val_accuracy: 0.9545
# Epoch 90/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0730 - accuracy: 0.9744 - val_loss: 0.1084 - val_accuracy: 0.9553
# Epoch 91/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0778 - accuracy: 0.9715 - val_loss: 0.1088 - val_accuracy: 0.9545
# Epoch 92/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0797 - accuracy: 0.9711 - val_loss: 0.1088 - val_accuracy: 0.9545
# Epoch 93/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0774 - accuracy: 0.9692 - val_loss: 0.1088 - val_accuracy: 0.9545
# Epoch 94/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0742 - accuracy: 0.9735 - val_loss: 0.1089 - val_accuracy: 0.9545
# Epoch 95/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0723 - accuracy: 0.9750 - val_loss: 0.1086 - val_accuracy: 0.9553
# Epoch 96/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0797 - accuracy: 0.9725 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 97/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0702 - accuracy: 0.9746 - val_loss: 0.1093 - val_accuracy: 0.9553
# Epoch 98/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0772 - accuracy: 0.9725 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 99/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0672 - accuracy: 0.9768 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 100/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0694 - accuracy: 0.9736 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 101/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0734 - accuracy: 0.9738 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 102/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0700 - accuracy: 0.9750 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 103/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0753 - accuracy: 0.9703 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 104/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0673 - accuracy: 0.9744 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 105/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0756 - accuracy: 0.9709 - val_loss: 0.1092 - val_accuracy: 0.9530
# Epoch 106/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0697 - accuracy: 0.9762 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 107/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0721 - accuracy: 0.9717 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 108/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0721 - accuracy: 0.9731 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 109/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0703 - accuracy: 0.9756 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 110/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0731 - accuracy: 0.9731 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 111/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0729 - accuracy: 0.9735 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 112/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0669 - accuracy: 0.9744 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 113/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0712 - accuracy: 0.9754 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 114/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0686 - accuracy: 0.9740 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 115/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0732 - accuracy: 0.9715 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 116/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0723 - accuracy: 0.9750 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 117/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0659 - accuracy: 0.9750 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 118/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0707 - accuracy: 0.9733 - val_loss: 0.1090 - val_accuracy: 0.9545
# Epoch 119/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0766 - accuracy: 0.9727 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 120/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0713 - accuracy: 0.9746 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 121/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0628 - accuracy: 0.9774 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 122/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0663 - accuracy: 0.9746 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 123/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0731 - accuracy: 0.9725 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 124/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0687 - accuracy: 0.9735 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 125/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0711 - accuracy: 0.9748 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 126/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0723 - accuracy: 0.9752 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 127/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0674 - accuracy: 0.9735 - val_loss: 0.1089 - val_accuracy: 0.9545
# Epoch 128/500
# 81/81 [==============================] - 2s 27ms/step - loss: 0.0704 - accuracy: 0.9725 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 129/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0622 - accuracy: 0.9776 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 130/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0685 - accuracy: 0.9766 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 131/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0749 - accuracy: 0.9713 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 132/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0698 - accuracy: 0.9768 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 133/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0675 - accuracy: 0.9731 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 134/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0745 - accuracy: 0.9733 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 135/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0708 - accuracy: 0.9733 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 136/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0749 - accuracy: 0.9723 - val_loss: 0.1098 - val_accuracy: 0.9537
# Epoch 137/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0744 - accuracy: 0.9738 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 138/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0703 - accuracy: 0.9725 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 139/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0740 - accuracy: 0.9733 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 140/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0667 - accuracy: 0.9783 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 141/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0697 - accuracy: 0.9748 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 142/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0684 - accuracy: 0.9758 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 143/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0727 - accuracy: 0.9742 - val_loss: 0.1097 - val_accuracy: 0.9537
# Epoch 144/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0611 - accuracy: 0.9789 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 145/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0728 - accuracy: 0.9727 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 146/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0650 - accuracy: 0.9762 - val_loss: 0.1090 - val_accuracy: 0.9545
# Epoch 147/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0741 - accuracy: 0.9733 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 148/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0648 - accuracy: 0.9770 - val_loss: 0.1091 - val_accuracy: 0.9537
# Epoch 149/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0633 - accuracy: 0.9770 - val_loss: 0.1091 - val_accuracy: 0.9537
# Epoch 150/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0669 - accuracy: 0.9764 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 151/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0685 - accuracy: 0.9719 - val_loss: 0.1084 - val_accuracy: 0.9553
# Epoch 152/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0711 - accuracy: 0.9733 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 153/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0704 - accuracy: 0.9746 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 154/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0643 - accuracy: 0.9770 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 155/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0720 - accuracy: 0.9746 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 156/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0693 - accuracy: 0.9738 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 157/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0721 - accuracy: 0.9735 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 158/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0724 - accuracy: 0.9752 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 159/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0743 - accuracy: 0.9731 - val_loss: 0.1086 - val_accuracy: 0.9553
# Epoch 160/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0783 - accuracy: 0.9713 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 161/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0803 - accuracy: 0.9692 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 162/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0655 - accuracy: 0.9752 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 163/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0674 - accuracy: 0.9723 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 164/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0820 - accuracy: 0.9731 - val_loss: 0.1099 - val_accuracy: 0.9537
# Epoch 165/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0716 - accuracy: 0.9742 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 166/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0719 - accuracy: 0.9750 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 167/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0744 - accuracy: 0.9729 - val_loss: 0.1092 - val_accuracy: 0.9537
# Epoch 168/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0654 - accuracy: 0.9744 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 169/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0696 - accuracy: 0.9735 - val_loss: 0.1098 - val_accuracy: 0.9537
# Epoch 170/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0702 - accuracy: 0.9746 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 171/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0702 - accuracy: 0.9713 - val_loss: 0.1090 - val_accuracy: 0.9545
# Epoch 172/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0656 - accuracy: 0.9768 - val_loss: 0.1086 - val_accuracy: 0.9553
# Epoch 173/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0702 - accuracy: 0.9742 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 174/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0716 - accuracy: 0.9724 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 175/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0714 - accuracy: 0.9740 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 176/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0777 - accuracy: 0.9717 - val_loss: 0.1096 - val_accuracy: 0.9545
# Epoch 177/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0717 - accuracy: 0.9746 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 178/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0674 - accuracy: 0.9740 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 179/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0740 - accuracy: 0.9735 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 180/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0734 - accuracy: 0.9709 - val_loss: 0.1098 - val_accuracy: 0.9537
# Epoch 181/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0685 - accuracy: 0.9738 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 182/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0731 - accuracy: 0.9731 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 183/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0655 - accuracy: 0.9758 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 184/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0699 - accuracy: 0.9733 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 185/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0705 - accuracy: 0.9760 - val_loss: 0.1095 - val_accuracy: 0.9553
# Epoch 186/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0685 - accuracy: 0.9764 - val_loss: 0.1094 - val_accuracy: 0.9553
# Epoch 187/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0657 - accuracy: 0.9779 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 188/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0727 - accuracy: 0.9727 - val_loss: 0.1096 - val_accuracy: 0.9545
# Epoch 189/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0723 - accuracy: 0.9742 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 190/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0702 - accuracy: 0.9754 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 191/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0731 - accuracy: 0.9756 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 192/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0706 - accuracy: 0.9742 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 193/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0642 - accuracy: 0.9766 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 194/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0696 - accuracy: 0.9740 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 195/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0712 - accuracy: 0.9729 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 196/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0723 - accuracy: 0.9731 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 197/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0662 - accuracy: 0.9746 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 198/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0647 - accuracy: 0.9748 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 199/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0706 - accuracy: 0.9725 - val_loss: 0.1091 - val_accuracy: 0.9537
# Epoch 200/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0765 - accuracy: 0.9713 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 201/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0698 - accuracy: 0.9748 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 202/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0723 - accuracy: 0.9729 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 203/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0676 - accuracy: 0.9764 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 204/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0662 - accuracy: 0.9776 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 205/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0741 - accuracy: 0.9723 - val_loss: 0.1093 - val_accuracy: 0.9553
# Epoch 206/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0716 - accuracy: 0.9715 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 207/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0720 - accuracy: 0.9754 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 208/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0717 - accuracy: 0.9731 - val_loss: 0.1086 - val_accuracy: 0.9553
# Epoch 209/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0668 - accuracy: 0.9777 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 210/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0742 - accuracy: 0.9711 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 211/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0713 - accuracy: 0.9740 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 212/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0742 - accuracy: 0.9731 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 213/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0743 - accuracy: 0.9735 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 214/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0681 - accuracy: 0.9736 - val_loss: 0.1097 - val_accuracy: 0.9537
# Epoch 215/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0694 - accuracy: 0.9750 - val_loss: 0.1098 - val_accuracy: 0.9537
# Epoch 216/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0735 - accuracy: 0.9717 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 217/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0755 - accuracy: 0.9719 - val_loss: 0.1099 - val_accuracy: 0.9537
# Epoch 218/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0750 - accuracy: 0.9729 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 219/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0703 - accuracy: 0.9738 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 220/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0601 - accuracy: 0.9785 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 221/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0688 - accuracy: 0.9738 - val_loss: 0.1097 - val_accuracy: 0.9537
# Epoch 222/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0705 - accuracy: 0.9723 - val_loss: 0.1099 - val_accuracy: 0.9537
# Epoch 223/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0721 - accuracy: 0.9709 - val_loss: 0.1098 - val_accuracy: 0.9537
# Epoch 224/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0726 - accuracy: 0.9742 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 225/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0748 - accuracy: 0.9735 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 226/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0735 - accuracy: 0.9735 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 227/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0752 - accuracy: 0.9735 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 228/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0733 - accuracy: 0.9729 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 229/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0675 - accuracy: 0.9750 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 230/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0755 - accuracy: 0.9738 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 231/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0691 - accuracy: 0.9754 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 232/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0672 - accuracy: 0.9756 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 233/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0677 - accuracy: 0.9758 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 234/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0653 - accuracy: 0.9783 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 235/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0671 - accuracy: 0.9736 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 236/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0758 - accuracy: 0.9727 - val_loss: 0.1097 - val_accuracy: 0.9537
# Epoch 237/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0759 - accuracy: 0.9731 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 238/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0693 - accuracy: 0.9772 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 239/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0657 - accuracy: 0.9772 - val_loss: 0.1097 - val_accuracy: 0.9537
# Epoch 240/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0692 - accuracy: 0.9729 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 241/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0714 - accuracy: 0.9744 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 242/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0666 - accuracy: 0.9746 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 243/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0700 - accuracy: 0.9744 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 244/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0692 - accuracy: 0.9760 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 245/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0742 - accuracy: 0.9721 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 246/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0768 - accuracy: 0.9723 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 247/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0705 - accuracy: 0.9752 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 248/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0701 - accuracy: 0.9744 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 249/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0712 - accuracy: 0.9752 - val_loss: 0.1090 - val_accuracy: 0.9545
# Epoch 250/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0791 - accuracy: 0.9705 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 251/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0684 - accuracy: 0.9760 - val_loss: 0.1092 - val_accuracy: 0.9537
# Epoch 252/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0665 - accuracy: 0.9754 - val_loss: 0.1097 - val_accuracy: 0.9537
# Epoch 253/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0769 - accuracy: 0.9674 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 254/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0722 - accuracy: 0.9713 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 255/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0649 - accuracy: 0.9781 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 256/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0686 - accuracy: 0.9742 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 257/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0749 - accuracy: 0.9723 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 258/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0701 - accuracy: 0.9729 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 259/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0698 - accuracy: 0.9750 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 260/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0666 - accuracy: 0.9744 - val_loss: 0.1096 - val_accuracy: 0.9553
# Epoch 261/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0698 - accuracy: 0.9719 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 262/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0667 - accuracy: 0.9758 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 263/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0676 - accuracy: 0.9733 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 264/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0773 - accuracy: 0.9709 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 265/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0655 - accuracy: 0.9756 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 266/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0751 - accuracy: 0.9725 - val_loss: 0.1092 - val_accuracy: 0.9537
# Epoch 267/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0752 - accuracy: 0.9719 - val_loss: 0.1097 - val_accuracy: 0.9537
# Epoch 268/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0766 - accuracy: 0.9717 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 269/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0671 - accuracy: 0.9774 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 270/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0679 - accuracy: 0.9766 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 271/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0701 - accuracy: 0.9770 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 272/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0639 - accuracy: 0.9772 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 273/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0788 - accuracy: 0.9699 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 274/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0675 - accuracy: 0.9766 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 275/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0762 - accuracy: 0.9727 - val_loss: 0.1095 - val_accuracy: 0.9553
# Epoch 276/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0664 - accuracy: 0.9733 - val_loss: 0.1096 - val_accuracy: 0.9545
# Epoch 277/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0736 - accuracy: 0.9740 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 278/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0709 - accuracy: 0.9740 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 279/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0662 - accuracy: 0.9776 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 280/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0692 - accuracy: 0.9736 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 281/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0727 - accuracy: 0.9735 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 282/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0709 - accuracy: 0.9740 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 283/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0707 - accuracy: 0.9729 - val_loss: 0.1095 - val_accuracy: 0.9530
# Epoch 284/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0747 - accuracy: 0.9735 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 285/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0703 - accuracy: 0.9742 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 286/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0709 - accuracy: 0.9742 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 287/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0782 - accuracy: 0.9695 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 288/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0760 - accuracy: 0.9715 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 289/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0714 - accuracy: 0.9721 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 290/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0685 - accuracy: 0.9744 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 291/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0718 - accuracy: 0.9731 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 292/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0666 - accuracy: 0.9762 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 293/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0714 - accuracy: 0.9754 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 294/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0689 - accuracy: 0.9736 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 295/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0750 - accuracy: 0.9733 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 296/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0769 - accuracy: 0.9740 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 297/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0694 - accuracy: 0.9723 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 298/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0714 - accuracy: 0.9738 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 299/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0746 - accuracy: 0.9721 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 300/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0722 - accuracy: 0.9738 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 301/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0679 - accuracy: 0.9756 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 302/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0724 - accuracy: 0.9738 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 303/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0656 - accuracy: 0.9774 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 304/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0757 - accuracy: 0.9719 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 305/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0713 - accuracy: 0.9750 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 306/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0669 - accuracy: 0.9752 - val_loss: 0.1093 - val_accuracy: 0.9553
# Epoch 307/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0709 - accuracy: 0.9756 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 308/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0694 - accuracy: 0.9729 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 309/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0727 - accuracy: 0.9750 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 310/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0655 - accuracy: 0.9727 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 311/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0680 - accuracy: 0.9744 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 312/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0661 - accuracy: 0.9733 - val_loss: 0.1093 - val_accuracy: 0.9553
# Epoch 313/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0694 - accuracy: 0.9758 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 314/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0723 - accuracy: 0.9738 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 315/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0730 - accuracy: 0.9725 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 316/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0761 - accuracy: 0.9731 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 317/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0703 - accuracy: 0.9709 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 318/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0713 - accuracy: 0.9725 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 319/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0777 - accuracy: 0.9725 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 320/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0655 - accuracy: 0.9756 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 321/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0680 - accuracy: 0.9740 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 322/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0713 - accuracy: 0.9717 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 323/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0733 - accuracy: 0.9738 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 324/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0696 - accuracy: 0.9742 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 325/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0673 - accuracy: 0.9774 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 326/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0735 - accuracy: 0.9731 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 327/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0786 - accuracy: 0.9703 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 328/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0761 - accuracy: 0.9727 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 329/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0725 - accuracy: 0.9750 - val_loss: 0.1090 - val_accuracy: 0.9545
# Epoch 330/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0698 - accuracy: 0.9754 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 331/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0679 - accuracy: 0.9764 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 332/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0618 - accuracy: 0.9811 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 333/500
# ...
# Epoch 391/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0656 - accuracy: 0.9752 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 392/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0665 - accuracy: 0.9748 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 393/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0706 - accuracy: 0.9756 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 394/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0695 - accuracy: 0.9733 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 395/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0679 - accuracy: 0.9764 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 396/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0691 - accuracy: 0.9735 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 397/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0634 - accuracy: 0.9754 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 398/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0751 - accuracy: 0.9721 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 399/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0691 - accuracy: 0.9735 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 400/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0715 - accuracy: 0.9754 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 401/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0702 - accuracy: 0.9746 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 402/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0720 - accuracy: 0.9727 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 403/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0758 - accuracy: 0.9723 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 404/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0672 - accuracy: 0.9766 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 405/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0681 - accuracy: 0.9754 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 406/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0703 - accuracy: 0.9729 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 407/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0729 - accuracy: 0.9729 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 408/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0743 - accuracy: 0.9725 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 409/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0772 - accuracy: 0.9723 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 410/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0718 - accuracy: 0.9752 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 411/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0677 - accuracy: 0.9785 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 412/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0643 - accuracy: 0.9783 - val_loss: 0.1089 - val_accuracy: 0.9537
# Epoch 413/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0726 - accuracy: 0.9736 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 414/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0623 - accuracy: 0.9762 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 415/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0696 - accuracy: 0.9746 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 416/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0733 - accuracy: 0.9711 - val_loss: 0.1097 - val_accuracy: 0.9537
# Epoch 417/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0706 - accuracy: 0.9748 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 418/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0695 - accuracy: 0.9736 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 419/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0737 - accuracy: 0.9725 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 420/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0727 - accuracy: 0.9731 - val_loss: 0.1096 - val_accuracy: 0.9537
# Epoch 421/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0810 - accuracy: 0.9686 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 422/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0728 - accuracy: 0.9736 - val_loss: 0.1090 - val_accuracy: 0.9545
# Epoch 423/500
# 81/81 [==============================] - 2s 28ms/step - loss: 0.0697 - accuracy: 0.9744 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 424/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0713 - accuracy: 0.9748 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 425/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0741 - accuracy: 0.9723 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 426/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0759 - accuracy: 0.9723 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 427/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0753 - accuracy: 0.9735 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 428/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0690 - accuracy: 0.9746 - val_loss: 0.1093 - val_accuracy: 0.9553
# Epoch 429/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0719 - accuracy: 0.9735 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 430/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0722 - accuracy: 0.9738 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 431/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0679 - accuracy: 0.9754 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 432/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0756 - accuracy: 0.9735 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 433/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0718 - accuracy: 0.9740 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 434/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0704 - accuracy: 0.9748 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 435/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0742 - accuracy: 0.9707 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 436/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0782 - accuracy: 0.9719 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 437/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0697 - accuracy: 0.9719 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 438/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0764 - accuracy: 0.9725 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 439/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0725 - accuracy: 0.9713 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 440/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0651 - accuracy: 0.9735 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 441/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0712 - accuracy: 0.9719 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 442/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0711 - accuracy: 0.9735 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 443/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0766 - accuracy: 0.9760 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 444/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0729 - accuracy: 0.9735 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 445/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0661 - accuracy: 0.9736 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 446/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0749 - accuracy: 0.9729 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 447/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0681 - accuracy: 0.9736 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 448/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0643 - accuracy: 0.9748 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 449/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0702 - accuracy: 0.9733 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 450/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0694 - accuracy: 0.9758 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 451/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0630 - accuracy: 0.9754 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 452/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0716 - accuracy: 0.9717 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 453/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0664 - accuracy: 0.9729 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 454/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0744 - accuracy: 0.9744 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 455/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0769 - accuracy: 0.9694 - val_loss: 0.1091 - val_accuracy: 0.9545
# Epoch 456/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0612 - accuracy: 0.9783 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 457/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0718 - accuracy: 0.9713 - val_loss: 0.1093 - val_accuracy: 0.9553
# Epoch 458/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0633 - accuracy: 0.9760 - val_loss: 0.1093 - val_accuracy: 0.9553
# Epoch 459/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0725 - accuracy: 0.9729 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 460/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0711 - accuracy: 0.9748 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 461/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0694 - accuracy: 0.9762 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 462/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0733 - accuracy: 0.9711 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 463/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0759 - accuracy: 0.9731 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 464/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0735 - accuracy: 0.9744 - val_loss: 0.1092 - val_accuracy: 0.9545
# Epoch 465/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0713 - accuracy: 0.9744 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 466/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0695 - accuracy: 0.9744 - val_loss: 0.1096 - val_accuracy: 0.9545
# Epoch 467/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0658 - accuracy: 0.9752 - val_loss: 0.1093 - val_accuracy: 0.9553
# Epoch 468/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0675 - accuracy: 0.9770 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 469/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0702 - accuracy: 0.9740 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 470/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0731 - accuracy: 0.9736 - val_loss: 0.1086 - val_accuracy: 0.9553
# Epoch 471/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0719 - accuracy: 0.9740 - val_loss: 0.1090 - val_accuracy: 0.9553
# Epoch 472/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0766 - accuracy: 0.9721 - val_loss: 0.1090 - val_accuracy: 0.9545
# Epoch 473/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0710 - accuracy: 0.9736 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 474/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0695 - accuracy: 0.9735 - val_loss: 0.1094 - val_accuracy: 0.9537
# Epoch 475/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0675 - accuracy: 0.9744 - val_loss: 0.1093 - val_accuracy: 0.9537
# Epoch 476/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0650 - accuracy: 0.9774 - val_loss: 0.1091 - val_accuracy: 0.9537
# Epoch 477/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0674 - accuracy: 0.9744 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 478/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0779 - accuracy: 0.9711 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 479/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0689 - accuracy: 0.9748 - val_loss: 0.1096 - val_accuracy: 0.9545
# Epoch 480/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0751 - accuracy: 0.9726 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 481/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0794 - accuracy: 0.9719 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 482/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0652 - accuracy: 0.9752 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 483/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0692 - accuracy: 0.9748 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 484/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0651 - accuracy: 0.9777 - val_loss: 0.1095 - val_accuracy: 0.9545
# Epoch 485/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0795 - accuracy: 0.9719 - val_loss: 0.1095 - val_accuracy: 0.9537
# Epoch 486/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0707 - accuracy: 0.9733 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 487/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0689 - accuracy: 0.9744 - val_loss: 0.1087 - val_accuracy: 0.9553
# Epoch 488/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0700 - accuracy: 0.9746 - val_loss: 0.1085 - val_accuracy: 0.9553
# Epoch 489/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0709 - accuracy: 0.9754 - val_loss: 0.1086 - val_accuracy: 0.9553
# Epoch 490/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0740 - accuracy: 0.9736 - val_loss: 0.1089 - val_accuracy: 0.9553
# Epoch 491/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0707 - accuracy: 0.9738 - val_loss: 0.1092 - val_accuracy: 0.9553
# Epoch 492/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0713 - accuracy: 0.9750 - val_loss: 0.1095 - val_accuracy: 0.9553
# Epoch 493/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0726 - accuracy: 0.9705 - val_loss: 0.1096 - val_accuracy: 0.9545
# Epoch 494/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0678 - accuracy: 0.9750 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 495/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0713 - accuracy: 0.9748 - val_loss: 0.1094 - val_accuracy: 0.9545
# Epoch 496/500
# 81/81 [==============================] - 2s 30ms/step - loss: 0.0650 - accuracy: 0.9764 - val_loss: 0.1093 - val_accuracy: 0.9545
# Epoch 497/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0668 - accuracy: 0.9746 - val_loss: 0.1091 - val_accuracy: 0.9553
# Epoch 498/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0710 - accuracy: 0.9735 - val_loss: 0.1088 - val_accuracy: 0.9553
# Epoch 499/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0713 - accuracy: 0.9738 - val_loss: 0.1086 - val_accuracy: 0.9553
# Epoch 500/500
# 81/81 [==============================] - 2s 29ms/step - loss: 0.0656 - accuracy: 0.9764 - val_loss: 0.1088 - val_accuracy: 0.9553
# 41/41 [==============================] - 0s 4ms/step - loss: 0.1088 - accuracy: 0.9553
# > 95.528

# %%
model_new_1 = keras.models.load_model("classification_deep_conv_model.h5")

# %%
model_new_1.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_input (InputLayer)    [(None, 50, 50, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 50, 50, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 50, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 947,426
# Trainable params: 945,250
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix,classification_report
y_pred = model_new_1.predict(X_test_images_np)
y_p = np.argmax(y_pred,axis=1)
y_true = np.argmax(y_test_labels_np,axis=1)
print('confusion matrix')
print(confusion_matrix(y_true,y_p))
# Out:
# confusion matrix
# [[1312   28]
#  [  41  241]]

# %%
print('Classification report')
print(classification_report(y_true,y_p))
# Out:
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1340
#            1       0.90      0.85      0.87       282
#
#     accuracy                           0.96      1622
#    macro avg       0.93      0.92      0.92      1622
# weighted avg       0.96      0.96      0.96      1622

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
op_layer = model_new_1.get_layer('dense_3').output
model_new = Model(inputs = model_new_1.input,outputs = op_layer)
train_new = sc.fit_transform(model_new.predict(X_train_images_np))
val_new = sc.fit_transform(model_new.predict(X_val_images_np))
test_new = sc.fit_transform(model_new.predict(X_test_images_np))

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf')
svm.fit(train_new,np.argmax(y_train_labels_np,axis=1))
print('Training score of svm',svm.score(train_new,np.argmax(y_train_labels_np,axis=1)))
print('validation score of svm :',svm.score(val_new,np.argmax(y_val_labels_np,axis=1)))
print('testing score of svm :',svm.score(test_new,np.argmax(y_test_labels_np,axis=1)))
# Out:
# Training score of svm 0.989010989010989
# validation score of svm : 0.9552814186584425
# testing score of svm : 0.9556103575832305

# %%
from xgboost import XGBClassifier
xg = XGBClassifier()
xg.fit(train_new,np.argmax(y_train_labels_np,axis=1))
print('Training score of xgb',xg.score(train_new,np.argmax(y_train_labels_np,axis=1)))
print('validation score of xgb :',xg.score(val_new,np.argmax(y_val_labels_np,axis=1)))
print('testing score of xgb :',xg.score(test_new,np.argmax(y_test_labels_np,axis=1)))
# Out:
# Training score of xgb 0.9901677270098322
# validation score of xgb : 0.9552814186584425
# testing score of xgb : 0.9549938347718866

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(train_new,np.argmax(y_train_labels_np,axis=1))
print('Training score of random_forest',rf.score(train_new,np.argmax(y_train_labels_np,axis=1)))
print('validation score of random_forest :',rf.score(val_new,np.argmax(y_val_labels_np,axis=1)))
print('testing score of random_forest :',rf.score(test_new,np.argmax(y_test_labels_np,axis=1)))
# Out:
# Training score of random_forest 1.0
# validation score of random_forest : 0.9599074787972244
# testing score of random_forest : 0.9580764488286067
